# %% [markdown]
# # Zonal Stats
#
# The objective of this notebook is to calculate zonal stats for a raster, given a set of polygons
#
# 1. Total population
# 2. Catagorical Values

# %% [markdown]
# ### Dependencies

# %%
from rasterstats import zonal_stats
import rasterio
import geopandas as gpd
import operator

# %% [markdown]
# ### Functions

# %%
def zone_stat(raster, band, polygon):
    """
    This function will calculate the zonal stats for each polygon within a raster
    requires gpd_df, raster, object and nodata value
    """
    
    band = raster.read(band)
    zone_stat = zonal_stats(polygon, band, affine=raster.meta['transform'], nodata = 0, stats = 'sum')
    return zone_stat

# %%
def zone_mode(raster, band, polygon):
    """ 
    This function will find the mode class within a polygon overlayed on top
    of a classified raster 
    requires gpd_df, raster, object
    """
    
    band = raster.read(band)
    zone_stat = zonal_stats(polygon, band, affine=raster.meta['transform'], categorical=True, category_map=cmap)
    return zone_stat

# %%
cmap = {
    
101: 'Temperate / arid',
102: 'Temperate / Semi-arid',
103: 'Temperate / sub-humid',
104: 'Temperate / humid',
211: 'Subtropic - warm / arid',
212: 'Subtropic - warm / semiarid',
213: 'Subtropic - warm / subhumid',
214: 'Subtropic - warm / humid',
221: 'Subtropic - cool / arid',
222: 'Subtropic - cool / semiarid',
223: 'Subtropic - cool / subhumid',
224: 'Subtropic - cool / humid',
311: 'Tropic - warm / arid',
312: 'Tropic - warm / semiarid',
313: 'Tropic - warm / subhumid',
314: 'Tropic - warm / humid',
321: 'Tropic - cool / arid',
322: 'Tropic - cool / semiarid',
323: 'Tropic - cool / subhumid',
324: 'Tropic - cool / humid',
400: 'Boreal'
    
}

# %% [markdown]
# ### Data In

# %%
data_raw = '/Users/cascade/Github/NTL/data/raw/'
data_temp = '/Users/cascade/Github/NTL/temp_data/'
data_interim = '/Users/cascade/Github/NTL/data/interim/'
ms_data = '/Users/cascade/Github/NTL/temp_data/MS_Data/'
erl_data = '/Users/cascade/Github/NTL/temp_data/ERL_data/'
downloads = '/Users/cascade/Downloads/'

# %%
poly_file = 'ERL_data/GHS_POP_GPW42000_urbanmerge'
poly_gpd = gpd.read_file(data_temp+poly_file+'.shp')

# %%
file_out = poly_file+'_PopTot'

# %%
# Use Zeros raster in analysis because it gets ride of any negative values that are used as NaN
# GHS_POP_GPW42000_GLOBE_R2015A_54009_1k_v1_0_Clip_zeros ... NaN and Neg values have been changed to zeros,
# and thus GHS_POP_GPW42000_GLOBE_R2015A_54009_1k_v1_0_Clip_zeros & 2015 version are OK to USE 2019-02-21


zeros_file = data_interim+'GHS_POP_GPW42000_GLOBE_R2015A_54009_1k_v1_0_Clip_zeros.tif'

#ghs_path = '/Users/cascade/Github/NTL/data/raw/ghs-pop/GHS_POP_GPW42000_GLOBE_R2015A_54009_1k_v1_0/'
#zeros_file = ghs_path+'GHS_POP_GPW42000_GLOBE_R2015A_54009_1k_v1_0.tif'


#raster = rasterio.open(raster_in)

# %%
raster_in = rasterio.open(zeros_file)

# %% [markdown]
# #### Reproject polygons if needed

# %%
# CRS({'proj': 'moll', 'lon_0': 0, 'x_0': 0, 'y_0': 0, 'ellps': 'WGS84', 'units': 'm', 'no_defs': True})
# above can be reprojected as 'i'init': 'esri:54009'}'
raster_in.meta['crs']
# Out:
# CRS({'proj': 'moll', 'lon_0': 0, 'x_0': 0, 'y_0': 0, 'ellps': 'WGS84', 'units': 'm', 'no_defs': True})

# %%
# Check if poly_gpd has a crs
print(poly_gpd.crs)

# assignet the crs correctly, check with qgis when in doubt 
poly_gpd.crs = {'init': 'epsg:4326'}

print(poly_gpd.crs)
# Out:
# {}
# {'init': 'epsg:4326'}

# %%
poly_gpd.head()
# Out:
#       osm_id   FID  country         city osm_type        lat       lon  \
# 0   89369215  5382  Algeria  Tamanrasset     town  22.785454  5.532446
# 1  252600742   624  Algeria    Boumerdès     town  36.758882  3.470596
# 2  253167052   195  Algeria       Thenia     town  36.724986  3.556935
# 3  253167208   150  Algeria     Zemmouri     town  36.786406  3.601221
# 4  253291208   436  Algeria    Lakhdaria     town  36.563944  3.596907
#
#                                             geometry
# 0  POLYGON ((5.512930562910484 22.80475188764244,...
# 1  POLYGON ((2.960095682991406 36.82071885667166,...
# 2  POLYGON ((3.610972972741118 36.75033076389462,...
# 3  POLYGON ((3.555512812300016 36.81191901602259,...
# 4  POLYGON ((3.548917172615572 36.58325611006445,...

# %%
# Reproject 

poly_gpd = poly_gpd.to_crs({'init': 'esri:54009'})
poly_gpd.head()
# Out:
#       osm_id   FID  country         city osm_type        lat       lon  \
# 0   89369215  5382  Algeria  Tamanrasset     town  22.785454  5.532446
# 1  252600742   624  Algeria    Boumerdès     town  36.758882  3.470596
# 2  253167052   195  Algeria       Thenia     town  36.724986  3.556935
# 3  253167208   150  Algeria     Zemmouri     town  36.786406  3.601221
# 4  253291208   436  Algeria    Lakhdaria     town  36.563944  3.596907
#
#                                             geometry
# 0  POLYGON ((525405.4525564685 2791029.461868489,...
# 1  POLYGON ((258405.4525564685 4431029.461868489,...
# 2  POLYGON ((315405.4525564685 4423029.461868487,...
# 3  POLYGON ((310405.4525564685 4430029.461868489,...
# 4  POLYGON ((310405.4525564685 4404029.461868488,...

# %% [markdown]
# #### Mask out zeros for rasters
#
# If you haven't be sure to make a new raster where NaN and neg. values are set to zero

# %%
# kwargs = raster_in.meta
# kwargs

# %%
# make mask of nodata as zeros
# mask = raster_in.read(1)
# mask[mask <= 0] = 0

# %%
# Update kwargs (change in data type)
# kwargs.update(dtype=rasterio.float32, count = 1)

# with rasterio.open(data_interim+'GHS_POP_GPW42015_GLOBE_R2015A_54009_1k_v1_0_Clip_zeros.tif', 'w', **kwargs) as dst:
#         dst.write_band(1, mask.astype(rasterio.float32))

# %% [markdown]
# ### Analysis

# %%
zonalstats_towns = zone_stat(raster_in, 1, poly_gpd)

# %%
poly_gpd['PopTot'] = gpd.GeoDataFrame.from_dict(zonalstats_towns)
poly_gpd
# Out:
#           osm_id    FID       country                 city osm_type  \
# 0       89369215   5382       Algeria          Tamanrasset     town
# 1      252600742    624       Algeria            Boumerdès     town
# 2      253167052    195       Algeria               Thenia     town
# 3      253167208    150       Algeria             Zemmouri     town
# 4      253291208    436       Algeria            Lakhdaria     town
# 5836  14.138815 -16.076391  POLYGON ((-1580594.547443531 1747029.461868489...
# 5837  14.759407 -17.438455  POLYGON ((-1699594.547443531 1825029.461868489...
# 5838  14.693425 -17.447938  POLYGON ((-1699594.547443531 1825029.461868489...
# 5839   8.479004 -13.267950  POLYGON ((-1323594.547443532 1050029.461868489...
# 5840   7.962065 -11.736650  POLYGON ((-1170594.547443531 987029.4618684892...
# 5841   7.885936 -11.186390  POLYGON ((-1113594.547443531 978029.461868489,...
# 5842   8.642281 -10.971631  POLYGON ((-1095594.547443531 1072029.461868489...
# 5843   9.125073 -12.919337  POLYGON ((-1285594.547443531 1128029.461868489...
# 5844   8.884740 -12.049120  POLYGON ((-1197594.547443531 1102029.461868489...
# 5845   8.338977 -13.069573  POLYGON ((-1302594.547443531 1030029.461868489...
# 5846  10.859545   0.204312  POLYGON ((18405.45255646855 1343029.461868489,...
# 5847  10.357191   0.476886  POLYGON ((45405.45255646854 1279029.461868489,...
# 5848   6.423115   1.210469  POLYGON ((118405.4525564685 797029.4618684892,...
# 5849   6.910608   0.632045  POLYGON ((62405.45255646854 857029.4618684892,...
# 5850   8.983319   1.143815  POLYGON ((112405.4525564685 1114029.461868489,...
# 5851   6.130419   1.215829  POLYGON ((114405.4525564685 777029.4618684892,...
# 5852   9.548767   1.198086  POLYGON ((114405.4525564685 1184029.461868489,...
# 5853   7.532060   1.121948  POLYGON ((111405.4525564686 933029.4618684894,...
#
#             PopTot
# 0     2.833428e+04
# 1     3.873888e+06
# 2     2.574931e+04
# 3     1.952352e+04
# 4     5.083199e+04
# 5     3.368617e+05
# 6     2.577718e+04
# 7     4.559333e+04
# 8     5.523000e+03
# 9     8.602000e+03
# 10    1.998621e+04
# 11    1.142530e+04
# 12    4.774413e+04
# 13    2.078266e+04
# 14    3.873888e+06
# 15    3.873888e+06
# 16    3.873888e+06
# 17    3.873888e+06
# 18    3.873888e+06
# 19    3.873888e+06
# 20    3.873888e+06
# 21    3.873888e+06
# 22    3.873888e+06
# 23    3.873888e+06
# 24    3.873888e+06
# 25    3.873888e+06
# 26    3.873888e+06
# 27    5.786861e+04
# 28    5.751858e+04
# 29    3.873888e+06
# ...            ...
# 5824  6.147959e+04
# 5825  1.872140e+05
# 5826  1.923622e+05
# 5827  2.175569e+06
# 5828  2.175569e+06
# 5829  3.064240e+05
# 5830  6.683001e+05
# 5831  6.320298e+04
# 5832  3.063805e+05
# 5833  2.175569e+06
# 5834  3.865013e+04
# 5835  9.555926e+04
# 5836  3.077639e+05
# 5837  2.175569e+06
# 5838  2.175569e+06
# 5839  6.553401e+05
# 5840  1.440784e+05
# 5841  1.271411e+05
# 5842  1.237009e+05
# 5843  2.928944e+04
# 5844  9.394373e+04
# 5845  3.996384e+04
# 5846  1.339467e+05
# 5847  6.043917e+04
# 5848  5.989376e+04
# 5849  9.189903e+04
# 5850  1.527777e+05
# 5851  1.298820e+06
# 5852  2.053903e+05
# 5853  1.094548e+05
#
# [5854 rows x 9 columns]

# %%
# check for zeros or strange data points

neg_df = poly_gpd[poly_gpd.PopTot < 0]
neg_df
# Out:
# Empty GeoDataFrame
# Columns: [osm_id, FID, country, city, osm_type, lat, lon, geometry, PopTot]
# Index: []

# %%
null = poly_gpd[poly_gpd.PopTot.isna()]
null
# Out:
# Empty GeoDataFrame
# Columns: [osm_id, FID, country, city, osm_type, lat, lon, geometry, PopTot]
# Index: []

# %% [markdown]
# ### zero out missing data for aezraster

# %%
# aezraster = rasterio.open(data_interim+'ssa-aez09-raster.tif')

# %%
# aezraster.meta

# %%
# import numpy as np

# np.unique(aezraster.read(1))

# %%
# maskaez = aezraster.read(1)
# maskaez[maskaez <= 0] = 0

# %%
# aez_kwargs = aezraster.meta
# aez_kwargs

# %%
# Update kwargs (change in data type)
# kwargs.update(dtype=rasterio.float32, count = 1)

# with rasterio.open(data_interim+'ssa-aez09-raster-zeros.tif', 'w', **aez_kwargs) as dst:
#         dst.write_band(1, maskaez.astype(rasterio.float64))

# %%
# import numpy as np
# np.unique(maskaez)

# %%
aezraster_zeros = rasterio.open(data_interim+'ssa-aez09-raster-zeros.tif')

# %%
aezraster_zeros.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float64',
#  'nodata': -9999.0,
#  'width': 9720,
#  'height': 9159,
#  'count': 1,
#  'crs': CRS({'init': 'epsg:4326'}),
#  'transform': Affine(0.0083333333333333, 0.0, -27.174992029555,
#         0.0, -0.0083333333333333, 38.53333449158769)}

# %%
# If needed, change crs back for gpd 

print(poly_gpd.crs)
poly_gpd = poly_gpd.to_crs({'init': 'epsg:4326'})
poly_gpd.head()
# Out:
# {'init': 'esri:54009'}
#       osm_id   FID  country         city osm_type        lat       lon  \
# 0   89369215  5382  Algeria  Tamanrasset     town  22.785454  5.532446
# 1  252600742   624  Algeria    Boumerdès     town  36.758882  3.470596
# 2  253167052   195  Algeria       Thenia     town  36.724986  3.556935
# 3  253167208   150  Algeria     Zemmouri     town  36.786406  3.601221
# 4  253291208   436  Algeria    Lakhdaria     town  36.563944  3.596907
#
#                                             geometry        PopTot
# 0  POLYGON ((5.512930562910484 22.80475188764244,...  2.833428e+04
# 1  POLYGON ((2.960095682991406 36.82071885667165,...  3.873888e+06
# 2  POLYGON ((3.610972972741117 36.7503307638946, ...  2.574931e+04
# 3  POLYGON ((3.555512812300016 36.81191901602259,...  1.952352e+04
# 4  POLYGON ((3.548917172615572 36.58325611006445,...  5.083199e+04

# %%
aez_class = zone_mode(aezraster_zeros, 1, poly_gpd)
# Out:
# /anaconda3/lib/python3.7/site-packages/rasterstats/io.py:294: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")

# %%
foo = {}
cat =[]

for i in aez_class:
    if i == foo:
        mode = 'NoClass'
    else:
            mode = (max(i.items(), key=operator.itemgetter(1))[0])
    cat.append((mode))

# %%
len(cat)
# Out:
# 5854

# %%
poly_gpd['aez_class'] = gpd.GeoDataFrame.from_dict(cat)
poly_gpd.head(6)
# Out:
#       osm_id   FID  country             city osm_type        lat       lon  \
# 0   89369215  5382  Algeria      Tamanrasset     town  22.785454  5.532446
# 1  252600742   624  Algeria        Boumerdès     town  36.758882  3.470596
# 2  253167052   195  Algeria           Thenia     town  36.724986  3.556935
# 3  253167208   150  Algeria         Zemmouri     town  36.786406  3.601221
# 4  253291208   436  Algeria        Lakhdaria     town  36.563944  3.596907
# 5  253292622   257  Algeria  Draâ Ben Khedda     town  36.733332  3.958769
#
#                                             geometry        PopTot  \
# 0  POLYGON ((5.512930562910484 22.80475188764244,...  2.833428e+04
# 1  POLYGON ((2.960095682991406 36.82071885667165,...  3.873888e+06
# 2  POLYGON ((3.610972972741117 36.7503307638946, ...  2.574931e+04
# 3  POLYGON ((3.555512812300016 36.81191901602259,...  1.952352e+04
# 4  POLYGON ((3.548917172615572 36.58325611006445,...  5.083199e+04
# 5  POLYGON ((3.842424792309737 36.82951907750195,...  3.368617e+05
#
#                      aez_class
# 0         Tropic - cool / arid
# 1  Subtropic - warm / subhumid
# 2  Subtropic - warm / subhumid
# 3  Subtropic - warm / subhumid
# 4  Subtropic - warm / subhumid
# 5  Subtropic - warm / subhumid

# %%
# write files out

poly_gpd.to_file(data_temp+file_out+".shp", driver='ESRI Shapefile')
poly_gpd.to_csv(data_temp+file_out+'.csv')

# %% [markdown]
# # Attempt at some graphics

# %%
towns = 'AFR_PPP_2015_adj_v2_pop_towns.shp'
towns_gpd = gpd.read_file(ms_data+towns)
towns_gpd.shape

# %%
cities = 'AFR_PPP_2015_adj_v2_pop.shp'
cities_gpd = gpd.read_file(ms_data+cities)
cities_gpd.shape

# %%
type(towns)

# %%
import pandas as pd

urban_concat = pd.concat([towns_gpd, cities_gpd])
urban_concat.shape

# %%
test_df = urban_concat[urban_concat.PopTot <= 250000000]
len(test_df)

# %%
test_df_drop = test_df.drop_duplicates('PopTot', keep=False)
len(test_df_drop)

# %%
ax = sns.boxplot(x = 'PopTot', y = 'country', data = test_df)
ax.set(xscale="log")

# %%
import matplotlib

#from matplotlib.pyplot import figure
#figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.savefig('WP2015.png', dpi=700,  bbox_inches='tight')

ax = sns.boxplot(x = 'PopTot', y = 'country', data = test_df_drop)
ax.set(xscale="log")

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)

# %%
import matplotlib.pyplot as plt
plt.show()
plt.savefig('WP2015.png', bbox_inches='tight')

# %%
fig = ax.get_figure()
fig.savefig('WP2015.png')

# %% [markdown]
# ### Count

# %%
city_file = 'LS15_w001001_Clip_1500c300_polyoverlap.shp'
town_file = 'LS15_w001001_Clip_1500c300_polyoverlap_towns.shp'

# %%
poly_gpd_city = gpd.read_file(downloads+city_file)
poly_gpd_town= gpd.read_file(downloads+town_file)

# %%
poly_gpd_city.shape

# %%
poly_gpd_town.shape

# %%
poly_gpd_town['Unique'] = poly_gpd_town.FID.astype(str)+poly_gpd_town['osm_type']
poly_gpd_town.head()

# %%
poly_gpd_city['Unique'] = poly_gpd_city.FID.astype(str)+poly_gpd_city['osm_type']
poly_gpd_city.head()

# %%
import pandas as pd
urban_concat = pd.concat([poly_gpd_city, poly_gpd_town])

# %%
urban_concat.head(6)

# %%
test_df_drop = urban_concat.drop_duplicates('test', keep=False)

# %%
test_df_drop.shape

# %%
test_df_drop['osm_type'].value_counts()

# %%
test_df_drop.to_file(downloads+'test.shp', driver='ESRI Shapefile')
