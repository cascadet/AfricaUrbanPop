# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# data = [100, 50, 25, 12, 6, 3, 1]
# sort = np.sort(data)

a = 1
samples = 1000
data = np.random.power(a, samples)
sort = np.sort(data)

# %%
sort
# Out:
# array([0.00311261, 0.00312495, 0.0055146 , 0.00731099, 0.00733398,
#        0.00742912, 0.00756862, 0.00847379, 0.00896295, 0.00963203,
#        0.01061309, 0.01303205, 0.01367935, 0.0172627 , 0.01883865,
#        0.01964459, 0.01980812, 0.02052559, 0.02074251, 0.02078358,
#        0.02175354, 0.02308819, 0.02336402, 0.0233837 , 0.02420698,
#        0.02444629, 0.02529414, 0.02536049, 0.02689422, 0.02952148,
#        0.0307673 , 0.03095142, 0.03097285, 0.03400009, 0.03483104,
#        0.03528329, 0.0389026 , 0.03898856, 0.0401054 , 0.04075409,
#        0.04078051, 0.04258996, 0.04307856, 0.04526464, 0.04539193,
#        0.05179927, 0.05267254, 0.05357658, 0.05589886, 0.05995707,
#        0.0614896 , 0.06236956, 0.06380591, 0.06401327, 0.06454972,
#        0.06487514, 0.06518803, 0.06589289, 0.06668465, 0.06679928,
#        0.06781714, 0.06887727, 0.06895104, 0.06938814, 0.0695046 ,
#        0.07061546, 0.07130042, 0.0745854 , 0.07494081, 0.07545507,
# ...

# %%
X1_zipf = (sort)
Y1_zipf = (list(range(1, len(X1_zipf)+1)))
Y1_zipf = Y1_zipf[::-1]

plt.scatter(X1_zipf, Y1_zipf, marker='.', color='Red', s=100, alpha = 0.5)
#sns.regplot(X1_zipf, Y1_zipf)

# %%
fit = ss.linregress(X1_zipf, Y1_zipf)

# %%
fit
# Out:
# LinregressResult(slope=-1021.5249173679014, intercept=997.9923084832401, rvalue=-0.9994545867284903, pvalue=0.0, stderr=1.068413215915802)
